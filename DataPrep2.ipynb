# %%
import numpy as np
import pandas as pd

# %%
airports = pd.read_csv('airports.csv')

# %%
airports.head()
# Out:
#        id ident           type                  name  latitude_deg
# 0    6523   00A       heliport     Total Rf Heliport     40.070801  \
# 1  323361  00AA  small_airport  Aero B Ranch Airport     38.704022
# 2    6524  00AK  small_airport          Lowell Field     59.947733
# 3    6525  00AL  small_airport          Epps Airpark     34.864799
# 4  506791  00AN  small_airport  Katmai Lodge Airport     59.093287
#
#    longitude_deg  elevation_ft continent iso_country iso_region  municipality
# 0     -74.933601          11.0       NaN          US      US-PA      Bensalem  \
# 1    -101.473911        3435.0       NaN          US      US-KS         Leoti
# 2    -151.692524         450.0       NaN          US      US-AK  Anchor Point
# 3     -86.770302         820.0       NaN          US      US-AL       Harvest
# 4    -156.456699          80.0       NaN          US      US-AK   King Salmon
#
#   scheduled_service gps_code iata_code local_code home_link wikipedia_link
# ...

# %%
df_euro = airports[airports['continent'] == 'EU']
df_euro2 = df_euro[df_euro['iso_country'] != 'RU']

# %%
df_euro2['iso_country'].unique()
# Out:
# array(['GB', 'AD', 'AL', 'XK', 'AT', 'BA', 'BE', 'BG', 'IS', 'BY', 'UA',
#        'CH', 'CZ', 'SK', 'DE', 'DK', 'EE', 'FI', 'GG', 'JE', 'IM', 'NL',
#        'IE', 'FO', 'LU', 'NO', 'PL', 'ES', 'PT', 'SE', 'LV', 'LT', 'FR',
#        'GR', 'HR', 'HU', 'IT', 'KZ', 'LI', 'SM', 'SI', 'MT', 'MC', 'RO',
#        'TR', 'MD', 'MK', 'GI', 'RS', 'ME', 'GE', 'VA'], dtype=object)

# %%
df_euro3 = df_euro2[df_euro2['iso_country'] != 'UA']

# %%
df_euro3.head()
# Out:
#            id    ident      type
# 10933  307979      ABE    closed  \
# 10934  302247      ABL    closed
# 10939  318235  AD-0001  heliport
# 10940  338490  AD-0002    closed
# 10941   41841   AD-ALV  heliport
#
#                                                     name  latitude_deg
# 10933                                       RAF Calveley     53.113333  \
# 10934                                   RNAS/RAF Calshot     50.819913
# 10939                          Terra Guindaldes Heliport     42.546257
# 10940              Arinsal (Coll de la Botella) Heliport     42.544983
# 10941  Andorra la Vella (Our Lady of Meritxell Hospit...     42.511228
#
#        longitude_deg  elevation_ft continent iso_country iso_region
# 10933      -2.603889           NaN        EU          GB     GB-ENG  \
# 10934      -1.306772           NaN        EU          GB     GB-ENG
# 10939       1.519160           NaN        EU          AD      AD-04
# ...
